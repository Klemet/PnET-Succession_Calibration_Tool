# %% [markdown]
# # Building the jupyter book from the notebooks of this repository
#
# [Jupyter book](https://jupyterbook.org/stable/) is a program that is used to transform a set of Jupyter notebooks into different types of publication format, including a static website with HTML pages. This allows us to create a documentation website that can be hosted on github pages.
#
# This notebook has a cell that calls the program directly from a terminal to build the HTML files, and then put them in the `/docs` folders where they will be used by Github pages to host the website.
#
# [Jupyter book](https://jupyterbook.org/stable/) now has a new version, 2.0, which uses the [Myst syntax and program](https://mystmd.org/) (made by the same team) to create the site. These commands adapt to this new way of working that is different from Jupyter book v1.
#
# **To add new notebooks to the final website, edit the file `myst.yml` which contains the list of files that will be used in the final html book.**

# %%
# This cell is not Python code; it runs the commands directly in the terminal.

# This command puts us in the right folder, where the myst setting files are to run the rest of the commands
# %cd /calibrationFolder/calibrationJupyterBook

# We temporarely set an environment variable that will be used by myst to know what will
# be the URL of the website that will use the HTML pages we will generate, so that
# the links in the pages point to the right place.
# %env BASE_URL=https://klemet.github.io/PnET-Succession_Calibration_Tool

# Here, we use HOST=0.0.0.0 to set an environment variable before launching the build
# This is because Jupyter book and Myst need to temporarely launch a web server during the building
# of the html pages of the book; and this web server is launched on 127.0.0.1, which is unavailable
# from inside the Docker container we use to launch these scripts.
# By putting it temporarely on 0.0.0.0, we make it accessible from inside the Docker container, 
# and everything works.
# !HOST=0.0.0.0 jupyter book build --html --port 3000 --keep-host

# We remove the previous version of the site in the docs folder
# !rm -rf ../docs/*

# We copy the new version of the site from the build folder to the docs folder
# !mv ./_build/html/* ../docs

# We remove the build folder, as it's not needed anymore.
# !rm -rf ./_build
# Out:
# /calibrationFolder/calibrationJupyterBook
# env: BASE_URL=https://klemet.github.io/PnET-Succession_Calibration_Tool
# /usr/local/lib/python3.12/dist-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# building myst-cli session with API URL: https://api.mystmd.org
# 🌎 Building Jupyter Book (via myst) site
# 🔍 Querying template metadata from https://api.mystmd.org/templates/site/myst/book-theme
# 🐕 Fetching template from https://github.com/myst-templates/book-theme/archive/refs/heads/main.zip
# 💾 Saved template to path _build/templates/site/myst/book-theme
# BASE_URL environment overwrite is set
# Building the site with a baseurl of "https://klemet.github.io/PnET-Succession_Calibration_Tool"
#
# The HOST environment variable is set to "0.0.0.0", this may cause issues for the web server.
#
# ⤵️  Installing web libraries (can take up to 60 s)
# npm notice
# npm notice New major version of npm available! 11.19.0 -> 12.0.2
# npm notice Changelog: https://github.com/npm/cli/releases/tag/v12.0.2
# npm notice To update run: npm install -g npm@12.0.2
# npm notice
#
# 📦 Installed web libraries in 12 s
# 📖 Built StartingCalibrationTest/2.Test_sim_functions.ipynb in 203 ms.
# 📖 Built StartingCalibrationTest/7.Calibrating_competition_between_species.ipynb in 661 ms.
# 📖 Built StartingCalibrationTest/8.Calibration_of_the_probability_of_establishment.ipynb in 658 ms.
# 📖 Built StartingCalibrationTest/1.Loading_functions.ipynb in 720 ms.
# 📖 Built intro.md in 746 ms.
# 📖 Built StartingCalibrationTest/Intro_CalibrationTest.ipynb in 742 ms.
# 📖 Built StartingCalibrationTest/9.Exporting_Parameters.ipynb in 735 ms.
# 🪄  Linked 7 DOIs from doi.org in 1.43 s for StartingCalibrationTest/3.Initial_Species_Parameters.ipynb
# 📖 Built StartingCalibrationTest/3.Initial_Species_Parameters.ipynb in 2.02 s.
# ⚠️  StartingCalibrationTest/6.Monoculture_ideal_conditions.ipynb:40 unknownSymbol, Unrecognized Unicode character "–" (8211)
#    AdjFracFol = FracFol + ((MaxFracFol – FracFol) * (fRad^{FracFolShape}))
# ⚠️  StartingCalibrationTest/6.Monoculture_ideal_conditions.ipynb:42 unknownSymbol, Unrecognized Unicode character "–" (8211)
#    AdjFolN = FolN + ((MaxFolN – FolN) * (fRad^{FolNShape}))
# 📖 Built StartingCalibrationTest/6.Monoculture_ideal_conditions.ipynb in 2.96 s.
# 🪄  Linked 1 DOI from doi.org in 2.59 s for StartingCalibrationTest/5.Getting_climate_and_soil_data.ipynb
# 📖 Built StartingCalibrationTest/5.Getting_climate_and_soil_data.ipynb in 3.17 s.
# 📖 Built StartingCalibrationTest/0.2.Goals_and_assumptions.ipynb in 3.22 s.
# 🪄  Linked 9 DOIs from doi.org in 2.81 s for StartingCalibrationTest/4.Getting_the_empirical_data.ipynb
# 📖 Built StartingCalibrationTest/4.Getting_the_empirical_data.ipynb in 3.48 s.
# 🪄  Linked 1 DOI from doi.org in 2.87 s for StartingCalibrationTest/100.Future_additions_todo.ipynb
# 📖 Built StartingCalibrationTest/100.Future_additions_todo.ipynb in 3.59 s.
# 🪄  Linked 1 DOI from doi.org in 3 s for StartingCalibrationTest/0.1.Some_important_notions.ipynb
# 📖 Built StartingCalibrationTest/0.1.Some_important_notions.ipynb in 3.83 s.
# ⛔️ StartingCalibrationTest/6.Monoculture_ideal_conditions.ipynb:41 Wikipedia pagenames should not contain "/" in link: https://en.wikipedia.org/wiki/Hazard_(golf)#/media/File:Oakland_Hills_Country_Club_-_Bloomfield_Hills,_Michigan.jpg
#    Only point to the final page name, do not include any other parts of the Wikipedia URL.
# 📚 Built 14 pages for project in 6.73 s.
#
#
# 	✨✨✨  Starting Book Theme  ✨✨✨
#
#
#
# 🔌 Server started on port 3000!  🥳 🎉
#
#
# 	👉  http://0.0.0.0:3000  👈
#
#
# (node:480) [DEP0169] DeprecationWarning: `url.parse()` behavior is not standardized and prone to errors that have security implications. Use the WHATWG URL API instead. CVEs are not issued for `url.parse()` vulnerabilities.
#
# 💌 GET  /index 200 - - 125.012 ms
# GET /startingcalibrationtest/intro-calibrationtest 200 - - 87.513 ms
# GET /startingcalibrationtest/goals-and-assumptions 200 - - 138.559 ms
# GET /startingcalibrationtest/loading-functions 200 - - 144.484 ms
# GET /startingcalibrationtest/some-important-notions 200 - - 129.073 ms
# 💌 GET  /startingcalibrationtest/test-sim-functions 200 - - 66.723 ms
# GET /startingcalibrationtest/getting-climate-and-soil-data 200 - - 279.829 ms
# 💌 GET  /startingcalibrationtest/initial-species-parameters 200 - - 267.307 ms
# GET /startingcalibrationtest/getting-the-empirical-data 200 - - 186.285 ms
# 💌 GET  /startingcalibrationtest/monoculture-ideal-conditions 200 - - 309.943 ms
# 💌 GET  /startingcalibrationtest/calibration-of-the-probability-of-establishment 200 - - 80.368 ms
# 💌 GET  /startingcalibrationtest/exporting-parameters 200 - - 112.602 ms
# GET /startingcalibrationtest/calibrating-competition-between-species 200 - - 130.352 ms
# GET /index.json 200 - - 104.310 ms
# GET /startingcalibrationtest/future-additions-todo 200 - - 125.223 ms
# 💌 GET  /startingcalibrationtest.intro-calibrationtest.json 200 - - 56.899 ms
# GET /startingcalibrationtest.loading-functions.json 200 - - 38.011 ms
# GET /startingcalibrationtest.goals-and-assumptions.json 200 - - 46.441 ms
# GET /startingcalibrationtest.some-important-notions.json 200 - - 53.134 ms
# GET /startingcalibrationtest.test-sim-functions.json 200 - - 25.772 ms
# 💌 GET  /startingcalibrationtest.getting-climate-and-soil-data.json 200 - - 65.767 ms
# GET /startingcalibrationtest.monoculture-ideal-conditions.json 200 - - 66.960 ms
# GET /startingcalibrationtest.initial-species-parameters.json 200 - - 57.693 ms
# GET /startingcalibrationtest.getting-the-empirical-data.json 200 - - 69.118 ms
# GET /startingcalibrationtest.calibrating-competition-between-species.json 200 - - 64.255 ms
# 💌 GET  /robots.txt 200 - - 1.890 ms
# 💌 GET  /sitemap.xml 200 - - 8.477 ms
# GET /startingcalibrationtest.exporting-parameters.json 200 - - 45.656 ms
# GET /startingcalibrationtest.calibration-of-the-probability-of-establishment.json 200 - - 55.004 ms
# GET /myst-theme.css 200 - - 25.505 ms
# GET /startingcalibrationtest.future-additions-todo.json 200 - - 42.898 ms
# 💌 GET  /sitemap_style.xsl 200 - - 1.111 ms
# 💌 GET  /favicon.ico 200 - - 110.157 ms
