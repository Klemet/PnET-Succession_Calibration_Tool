# %% [markdown]
# # Building the jupyter book from the notebooks of this repository
#
# [Jupyter book](https://jupyterbook.org/stable/) is a program that is used to transform a set of Jupyter notebooks into different types of publication format, including a static website with HTML pages. This allows us to create a documentation website that can be hosted on github pages.
#
# This notebook has a cell that calls the program directly from a terminal to build the HTML files, and then put them in the `/docs` folders where they will be used by Github pages to host the website.
#
# [Jupyter book](https://jupyterbook.org/stable/) now has a new version, 2.0, which uses the [Myst syntax and program](https://mystmd.org/) (made by the same team) to create the site. These commands adapt to this new way of working that is different from Jupyter book v1.
#
# **To add new notebooks to the final website, edit the file `myst.yml` which contains the list of files that will be used in the final html book.**

# %%
# This cell is not Python code; it runs the commands directly in the terminal.

# This command puts us in the right folder, where the myst setting files are to run the rest of the commands
# %cd /calibrationFolder/calibrationJupyterBook

# We temporarely set an environment variable that will be used by myst to know what will
# be the URL of the website that will use the HTML pages we will generate, so that
# the links in the pages point to the right place.
# %env BASE_URL=https://klemet.github.io/PnET-Succession_Calibration_Tool

# Here, we use HOST=0.0.0.0 to set an environment variable before launching the build
# This is because Jupyter book and Myst need to temporarely launch a web server during the building
# of the html pages of the book; and this web server is launched on 127.0.0.1, which is unavailable
# from inside the Docker container we use to launch these scripts.
# By putting it temporarely on 0.0.0.0, we make it accessible from inside the Docker container, 
# and everything works.
# !HOST=0.0.0.0 jupyter book build --html --port 3000 --keep-host

# We remove the previous version of the site in the docs folder
# !rm -rf ../docs/*

# We copy the new version of the site from the build folder to the docs folder
# !mv ./_build/html/* ../docs

# We remove the build folder, as it's not needed anymore.
# !rm -rf ./_build
# Out:
# /calibrationFolder/calibrationJupyterBook
# env: BASE_URL=https://klemet.github.io/PnET-Succession_Calibration_Tool
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# building myst-cli session with API URL: https://api.mystmd.org
# 🌎 Building Jupyter Book (via myst) site
# 🔍 Querying template metadata from https://api.mystmd.org/templates/site/myst/book-theme
# 🐕 Fetching template from https://github.com/myst-templates/book-theme/archive/refs/heads/main.zip
# 💾 Saved template to path _build/templates/site/myst/book-theme
# BASE_URL environment overwrite is set
# Building the site with a baseurl of "https://klemet.github.io/PnET-Succession_Calibration_Tool"
#
# The HOST environment variable is set to "0.0.0.0", this may cause issues for the web server.
#
# ⤵️  Installing web libraries (can take up to 60 s)
# npm notice
# npm notice New major version of npm available! 11.16.0 -> 12.0.2
# npm notice Changelog: https://github.com/npm/cli/releases/tag/v12.0.2
# npm notice To update run: npm install -g npm@12.0.2
# npm notice
#
# 📦 Installed web libraries in 12 s
# 📖 Built StartingCalibrationTest/7.Calibrating_competition_between_species.ipynb in 628 ms.
# 📖 Built StartingCalibrationTest/8.Calibration_of_the_probability_of_establishment.ipynb in 631 ms.
# 📖 Built intro.md in 696 ms.
# 📖 Built StartingCalibrationTest/Intro_CalibrationTest.ipynb in 691 ms.
# 📖 Built StartingCalibrationTest/1.Loading_functions.ipynb in 759 ms.
# 📖 Built StartingCalibrationTest/2.Test_sim_functions.ipynb in 767 ms.
# 🪄  Linked 8 DOIs from doi.org in 1.68 s for StartingCalibrationTest/3.Initial_Species_Parameters.ipynb
# 📖 Built StartingCalibrationTest/3.Initial_Species_Parameters.ipynb in 2.16 s.
# ⚠️  StartingCalibrationTest/6.Monoculture_ideal_conditions.ipynb:40 unknownSymbol, Unrecognized Unicode character "–" (8211)
#    AdjFracFol = FracFol + ((MaxFracFol – FracFol) * (fRad^{FracFolShape}))
# ⚠️  StartingCalibrationTest/6.Monoculture_ideal_conditions.ipynb:42 unknownSymbol, Unrecognized Unicode character "–" (8211)
#    AdjFolN = FolN + ((MaxFolN – FolN) * (fRad^{FolNShape}))
# 📖 Built StartingCalibrationTest/6.Monoculture_ideal_conditions.ipynb in 2.92 s.
# 🪄  Linked 8 DOIs from doi.org in 2.45 s for StartingCalibrationTest/4.Getting_the_empirical_data.ipynb
# 📖 Built StartingCalibrationTest/4.Getting_the_empirical_data.ipynb in 3.08 s.
# 📖 Built StartingCalibrationTest/0.2.Goals_and_assumptions.ipynb in 3.11 s.
# 🪄  Linked 1 DOI from doi.org in 2.64 s for StartingCalibrationTest/5.Getting_climate_and_soil_data.ipynb
# 📖 Built StartingCalibrationTest/5.Getting_climate_and_soil_data.ipynb in 3.15 s.
# 🪄  Linked 1 DOI from doi.org in 2.59 s for StartingCalibrationTest/0.1.Some_important_notions.ipynb
# 📖 Built StartingCalibrationTest/0.1.Some_important_notions.ipynb in 3.38 s.
# 🪄  Linked 1 DOI from doi.org in 2.67 s for StartingCalibrationTest/100.Future_additions_todo.ipynb
# 📖 Built StartingCalibrationTest/100.Future_additions_todo.ipynb in 3.43 s.
# ⛔️ StartingCalibrationTest/6.Monoculture_ideal_conditions.ipynb:41 Wikipedia pagenames should not contain "/" in link: https://en.wikipedia.org/wiki/Hazard_(golf)#/media/File:Oakland_Hills_Country_Club_-_Bloomfield_Hills,_Michigan.jpg
#    Only point to the final page name, do not include any other parts of the Wikipedia URL.
# 📚 Built 13 pages for project in 6.09 s.
#
#
# 	✨✨✨  Starting Book Theme  ✨✨✨
#
#
#
# 🔌 Server started on port 3000!  🥳 🎉
#
#
# 	👉  http://0.0.0.0:3000  👈
#
#
# (node:606) [DEP0169] DeprecationWarning: `url.parse()` behavior is not standardized and prone to errors that have security implications. Use the WHATWG URL API instead. CVEs are not issued for `url.parse()` vulnerabilities.
#
# 💌 GET  /startingcalibrationtest/intro-calibrationtest 200 - - 89.192 ms
# GET /index 200 - - 92.474 ms
# GET /startingcalibrationtest/goals-and-assumptions 200 - - 120.898 ms
# GET /startingcalibrationtest/loading-functions 200 - - 125.444 ms
# GET /startingcalibrationtest/some-important-notions 200 - - 111.142 ms
# 💌 GET  /startingcalibrationtest/test-sim-functions 200 - - 62.074 ms
# 💌 GET  /startingcalibrationtest/getting-climate-and-soil-data 200 - - 175.814 ms
# 💌 GET  /startingcalibrationtest/getting-the-empirical-data 200 - - 163.237 ms
# 💌 GET  /startingcalibrationtest/initial-species-parameters 200 - - 267.045 ms
# GET /startingcalibrationtest/monoculture-ideal-conditions 200 - - 305.315 ms
# 💌 GET  /startingcalibrationtest/calibration-of-the-probability-of-establishment 200 - - 151.885 ms
# GET /index.json 200 - - 117.663 ms
# GET /startingcalibrationtest/future-additions-todo 200 - - 120.585 ms
# GET /startingcalibrationtest.intro-calibrationtest.json 200 - - 97.675 ms
# GET /startingcalibrationtest/calibrating-competition-between-species 200 - - 127.554 ms
# 💌 GET  /startingcalibrationtest.loading-functions.json 200 - - 35.381 ms
# GET /startingcalibrationtest.goals-and-assumptions.json 200 - - 50.195 ms
# GET /startingcalibrationtest.some-important-notions.json 200 - - 53.325 ms
# GET /startingcalibrationtest.test-sim-functions.json 200 - - 35.156 ms
# 💌 GET  /startingcalibrationtest.initial-species-parameters.json 200 - - 64.232 ms
# 💌 GET  /startingcalibrationtest.getting-climate-and-soil-data.json 200 - - 46.810 ms
# 💌 GET  /startingcalibrationtest.calibrating-competition-between-species.json 200 - - 58.324 ms
# GET /startingcalibrationtest.monoculture-ideal-conditions.json 200 - - 58.742 ms
# 💌 GET  /startingcalibrationtest.getting-the-empirical-data.json 200 - - 96.202 ms
# 💌 GET  /robots.txt 200 - - 1.656 ms
# GET /startingcalibrationtest.calibration-of-the-probability-of-establishment.json 200 - - 58.805 ms
# 💌 GET  /sitemap_style.xsl 200 - - 1.490 ms
# GET /startingcalibrationtest.future-additions-todo.json 200 - - 40.682 ms
# 💌 GET  /sitemap.xml 200 - - 19.912 ms
# 💌 GET  /myst-theme.css 200 - - 46.370 ms
# 💌 GET  /favicon.ico 200 - - 341.759 ms
