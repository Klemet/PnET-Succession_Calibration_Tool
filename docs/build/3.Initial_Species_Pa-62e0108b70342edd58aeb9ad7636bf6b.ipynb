# %% [markdown]
# ---
# # This cell contains abreviations that are used to display tooltips for the parameters names of PnET-Succession to make the documentation more readable. You can hide it if it is visible.
# abbreviations:
#     FolN: Foliar nitrogen content (in % by weight) for the leaves of the species.
#     SLWmax: Specific leaf weight at the top of the canopy.
#     SLWDel: Rate of change in the weight of the leaves from the top of the canopy (SLWmax) to each sublayer under the canopy.
#     MaxLAI: Maximum leaf area index (LAI) that a species can achieve in its lifetime (for an age cohort ?).
#     TOFol: Fraction of foliage biomass lost per year.
#     TORoot: Fraction of root biomass lost per year.
#     TOWood: Fraction of wood biomass lost per year.
#     AmaxA: Intercept of the relationship between foliar N and maximum net photosynthetic rate.
#     AmaxB: Slope of the relationship betwee foliar N and maximum net photosynthetic rate.
#     HalfSat: Half saturation light level for photosynthesis.
#     H1: Water stress parameter according to Feddes et al. (1978) (Fig. 59).
#     H2: Water stress parameter according to Feddes et al. (1978) (Fig. 59).
#     H3: Water stress parameter according to Feddes et al. (1978) (Fig. 59).
#     H4: Water stress parameter according to Feddes et al. (1978) (Fig. 59).
#     PsnAgeRed: Reduction factor of photosynthesis as the age of an age cohort increases.
#     LeafOnMinT: Minimum temperature for activate growing season.
#     PsnTMin: Minimum average daytime temperature for photosynthesis.
#     PsnTOpt: Optimal average daytime temperature for photosynthesis.
#     PsnTMax: Maximum average daytime temperature for photosynthesis.
#     ColTol: Cold tolerance (coldest temperature that the species can survive).
#     k (parameter): Canopy light attenuation constant (light extinction coefficient).
#     DNSC: Proportion of Non Structural (ressources) carbon from the total activate biomass of the cohort that will be maintained as long as net photosynthesis exceeds maintenance respiration.
#     FracBelowG: Fraction of non-foliar biomass that is allocated belowground (root pool).
#     EstMoist: Scaling parameter that changes the maximum expected value of fWater when computing the probability of establishment.
#     EstRad: Scaling parameter that changes the maximum expected value of fRad when computing the probability of establishment.
#     FracFol: Fraction of the active woody biomass (above or belowground) of a cohort that determines the amount of foliage maintained each year.
#     FrActWd: Shape parameter of the negative exponential function that calculates the amount of woody biomass that has active xylem capable of supporting foliage.
#     CO2HalfSatEff: Slope coefficient used to reduce HalfSat (= increase shade tolerance) as CO2 concentration increase.
#     CO2AMaxBEff: Proportional change in AmaxB at 550ppm CO2 relative to 350ppm.
#     O3StomataSens: Species susceptibility of the stomata to ozone-induced sluggishness.
#     O3GrowthSens: Species susceptibility to ozone-induced tissue damage.
#     MaxFolN: Controls the dynamic response of foliar nitrogen (FolN) to light.
#     FolNShape: Controls the dynamic response of foliar nitrogen (FolN) to light.
#     MaxFracFol: Controls the dynamic response of the fraction of Foliage (FracFol) to light.
#     FracFolShape: Controls the dynamic response of the fraction of Foliage (FracFol) to light.
#     LifeForm: Specifies the life form (stature) of the species to determine the limits to the species major canopy layer.
#     MossScalar: Unit converter from biomass to depth in the case of a pseudo species (moss).
#     MaxCanopyLayer: Caps the number of canopy layers implemented in the model.
#     LayerThreshRatio: Define how age cohorts of a given species are grouped together into canopy layers. Correspond to the minimum ratio of cohort woody biomass density between two cohorts that will place them in different canopy layers.
#     PARunits: Indicates the units for PAR and HalfSat values. See Climate Input File for PAR and Species Parameters File for HalfSat.
#     IMAX: Defines the degree of subdivision into different canopy sublayers for each age cohort.
#     DVPD1: Coefficient for converting the vapor pressure deficit (VPD) into a reduction factor for photosynthesis caused by water pressure (fDVPD).
#     DVPD2: Coefficient for converting the vapor pressure deficit (VPD) into a reduction factor for photosynthesis caused by water pressure (fDVPD).
#     BFolResp: Define the Base Foliar Respiration Fraction (the foliar respiration as a fraction of the maximum photosynthetic rate).
#     MaintResp: Represents the loss of Non Structural Carbon (NSC) due to maintenance respiration as a fraction of the active wood biomass of the cohort.
#     Q10: Coefficient of the Q10 relationship to compute the foliar respiration.
#     FolLignin: Mass fraction of lignin in foliage tissue.
#     KWdLit: Annual decomposition rate of woody litter (decay constant k in equations).
#     InitialNSC: Amount of Non Structural Carbon assigned to newly established cohorts.
#     CFracBiomass: Carbon fraction of biomass by weight in an age cohort.
#     PrecipEvents: Number of precipitation events during a month.
#     PrecipEventsWithReplacement: Defines the logic of assignation of the precipitation from a precipitation event to the canopy sub layers.
#     ETExtCoeff: Canopy extinction coefficient to reduce soil water evaporation as LAI increases (because of shadow created by the canopy ?).
#     RETCropCoeff: Coefficient that scales the reference evapotranspiration (RET).
#     PreventEstablishment: Turns species establishment on new cells on or off.
#     Wythers: Turns the Wythers correction on or off.
#     DTEMP: Turns the PnET-II DTEMP temperature reduction factor on or off.
#     MaxPest: Tuning parameter to raise or lower the establishment probability of species by a same proportion.
#     AmaxFrac: Fraction of the early morning instantaneous photosynthetic rate that represents the mean daily photosynthetic rate.
#     InvertPest: Activates the optional inversion of the effect of fRad on the probability establishment as a function of HalfSat.
#     SoilIceDepth: Activates the optional simulation of soil ice depth and its effects on water leakage.
#     LeakageFrostDepth: Soil ice depth at which frozen soil no longer impedes soil drainage.
#     FrostFactor: Tuning parameter to adjust soil ice depth.
#     InitialCommunitiesSpinup: Specifies how the biomass of the initial age cohorts/communities in each cells are generated.
#     SpinupWaterStress: Activates waterlogging stress during spin up procedures.
#     Parallel: Specifies the number of CPU threads used for parallel execution.
#     CohortStacking: Specifies the canopy cohort processing method.
#     CanopySumScale: Scales the degree to which cumulativve canopy proportions cannot exceed 1.
#     Eric Gustafson: Former researcher (now retired) at the US Forest Service. Eric was largely responding for develloping the PnET-Succession extension of LANDIS-II.
#     Brian Sturtevant: Researcher at the US Forest Service. Has worked extensively with PnET-Succession and assisted in its development.
# ---

# %% [markdown]
# # Notebook 3 - Getting the initial parameters values

# %% [markdown]
# This notebook is used to either indicate the initial parameter values (before calibrating them) or find them for a given species using an combination of available datasets and the advice of Eric Gustafson in the [user guide of PnET-Succession v5.1](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf).
#
# Finding these initial values for your tree species might be the most work you will have to do here, especially for the "Core species parameters" (see below). Since I've made these notebooks with the goal of calibrating as many canadian tree species as possible, you'll find sources of data and functions to compute some parameters for canadian tree species. But if you're in the US or in Europe, or in another part of the world where previous LANDIS-II studies are scarce, you will have to to some digging.
#
# **At the end of this notebook, you should have three `.json` files containing your parameters for each species, in the format used by the rest of the functions in these notebooks : one for the core species parameters, one for the PnET species parameters, and one for the PnET generic parameters (see below for explanations about the terms). These three `.json` files should be in the folder `SpeciesParametersSets/Initial/`.
#
# :::{tip}
# Remember that as much as possible, it is best to get parameters values for your species in your study area, or near your study area, to avoid confusion with local variants or phenotypes. See [0.1.Some_important_notions.ipynb](0.1.Some_important_notions.ipynb) for more.
#
# Of course, some parameters (especially some core species parameters which represent global life history traits) don't need to be local; and for other, you will have a lot of difficulty finding more local estimates. It's alright, and it's part of the complexity in calibrating a complex model such as LANDIS-II and PnET-Succession. Just take the best values you find, note the limitations and potential implications or your choices on what the model will produce, and carry on !
# :::

# %% [markdown]
# ## What parameters are we talking about here, and what are the different categories of parameters ?

# %% [markdown]
# In this page, we will talk about :
#
# - **Core species parameters** : The species parameters used by the LANDIS-II core (e.g. Longevity, dispersal distance, etc.). These will go in the "core" species parameter file for LANDIS-II (indicated in the main scenario file).
# - **PnET species parameters** : The species parameters used by PnET Succession that will vary between species. These will go into the species parameters file of PnET Succession.
# - **PnET generic species parameters** : The species parameters used by PnET Succession that we will keep constant between species. These will go into the generic parameter file of PnET Succession. See below for recommendations on which parameters to put in this category.
# - **PnET generic parameters** : Other generic parameters of PnET Succession that are not related to species, but that are still crucial for the functionning of PnET Succession (PARunits, PrecipEvents, etc.).
#
# :::{note} Why should some species parameters be "generic" and constant accross species in PnET Succession ?
#
# [Gustafson and Miranda (2023)](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf) advises that several species parameters should be used as *generic species parameters*, meaning that their value should be the same between species, in order to facilitate the comprehension of competition processes. Quoting from them :
#
# > Use the GenericPnETSpeciesParameters file for all parameters that are not varied among species.  Set parameters that will be held constant for your particular experiment or study (e.g., MaintResp, InitialNSC, etc.)
#
# > Parameters that the model is highly sensitive to (for which common values should be used as much as possible) include: MaintResp, AmaxA, AmaxB, k, and FracBelowG.
#
# > Minimizing species differences in parameters such as SLWDel, PsnAgeRed, k, MaintResp, DNSC and FracBelowG, will make competitive interactions more predictable.  Hold these as close to each other as possible, varying other parameters to calibrate as much as possible within empirical limits.
# :::
#
# :::{note} Which PnET species parameters should be generic ?
#
# The choice depends on your species. As recommanded above by [Gustafson and Miranda (2023)](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf), using as many parameters as you can as constant and generic accross species will make competition and other processes in PnET Succession easier to interpret and understand. But sometimes, you will have to change these parameters between species so as to properly represent their differences.
#
# Here, I will start with the recommandations of [Gustafson and Miranda (2023)](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf) and make MaintResp, InitialNSC, k, FracBelowG, PsnAgeRed, DNSC similar between species. SLWDel, k, AmaxA and AmaxB will not be generic as they have to vary at least between evergreen and deciduous according to [Gustafson and Miranda (2023)](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf).
#
# The rest of the species parameters (see [here](./ReferencesAndData/Documentation/LANDIS-IIPnETextensionParametersInformation.xlsx) for a full list) like FolN, SLWmax, TOFol, TORoot, TOWood, HalfSat, H1, H2, H3, H4, LeafOnMinT, PsnTMin, PsnTOpt, EstMoist, EstRad, FracFol, FrActWd, SLWDel, k, AmaxA and AmaxB will change by species or by growth form/strategy (e.g. shade tolerant, etc.).
# :::

# %% [markdown]
# ## What parameters are we not using, currently ?
#
# Currently, I'm avoiding most optional parameter to reduce the complexity of the calibration. Here are the parameters that we will avoid.
#
# - MaxLAI: Maximum leaf area index (LAI) that a species can achieve in its lifetime (for an age cohort ?).
# - MaxFolN: Controls the dynamic response of foliar nitrogen (FolN) to light.
# - FolNShape: Controls the dynamic response of foliar nitrogen (FolN) to light.
# - PsnTMax: Maximum average daytime temperature for photosynthesis.
# - ColTol: Cold tolerance (coldest temperature that the species can survive).
# - CO2HalfSatEff: Slope coefficient used to reduce HalfSat (= increase shade tolerance) as CO2 concentration increase.
# - CO2AMaxBEff: Proportional change in AmaxB at 550ppm CO2 relative to 350ppm.
# - O3StomataSens: Species susceptibility of the stomata to ozone-induced sluggishness.
# - O3GrowthSens: Species susceptibility to ozone-induced tissue damage.
# - LifeForm: Specifies the life form (stature) of the species to determine the limits to the species major canopy layer (**needed if you want to simulate shrubs, which is a possibility !**)
# - MossScalar: Unit converter from biomass to depth in the case of a pseudo species (moss).
#
# However, we're most likely going to use these two optional parameters to better distinguish between pioneer and later successional species :
#
# - MaxFracFol: Controls the dynamic response of the fraction of Foliage (FracFol) to light.
# - FracFolShape: Controls the dynamic response of the fraction of Foliage (FracFol) to light.
#
# You can, of course, choose to set specific values for these parameters depending on your research question.

# %% [markdown]
# ## Sources of parameter values

# %% [markdown]
# Here, I recommand that you indicate the sources (articles, books, etc.) that you will use for your parameter values, so that you keep a clear trace of them.
#
# Several sources and references for parameter values will be considered here. I assign to them a number that is indicative of their pertinence related to our study (1 = highest pertinence), and so the priority in which the source will be used to take the initial parameters for the calibration. Here, the sources I'm using are simply studies where the parameters for the species I'm calibrating have already been published.
#
# - **(1)** [Gustafson and Miranda (2023)](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf) (the PnET v5.1 user guide, which contains many parameter values recommanded by Eric Gustafson, especially initial values to be used as starting points; see Table 1 page 74 for initial values, or pages 78-79; or pages 80-82 for calibrated values in of northern Wisconsin)
# - Other recommendations of [Gustafson and Miranda (2023)](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf)  :
#     - **(4)** [Aber et al. (1996)](https://link.springer.com/article/10.1007/BF00328606) : Fig 2 shows the relationship between Lean nitrogen concentration (in % of dry weight) and the parameter AmaxA from PnET.
#     - Some PnET parameters (e.g., SLWDel, AmaxA, AmaxB, Q10, DVPD1, DVPD2) are hard to estimate and most studies use generic values (e.g., **(5)** [Aber et al. 1995, Table 2](https://www.int-res.com/articles/cr/5/c005p207.pdf), **(6)** [Ollinger and Smith 2005, Table 1](https://link.springer.com/article/10.1007/s10021-005-0079-5)).
#     - **(7)** To calibrate the biomass of roots (via TORoot, FracBelowG), see the estimates of whole tree biomass of [Smith et al. 2006](https://books.google.ca/books?hl=fr&lr=&id=rNMHmlNynNsC&oi=fnd&pg=PP4&dq=Smith,+J.E.,+Heath,+L.S.,+Skog,+K.E.,+Birdsey,+R.A.+2006.+Methods+for+calculating+forest+ecosystem+and+harvested+carbon+with+standard+estimates+for+forest+types+of+the+United+States.+USDA+Forest+Service+General+Technical+Report+NE-343.+Northeastern+Research+Station,+Newtown+Square,+PA,+USA.+216+p.&ots=Urs7Cs4FtB&sig=zS2t0mlM9OAMVnifokfRNYAUnpk#v=onepage&q&f=false)
#
# - More recent articles about PnET-II :
#     - **(8)** [Suárez-Muñoz1 et al. 2021](https://www.frontiersin.org/journals/ecology-and-evolution/articles/10.3389/fevo.2021.653393/full) : calibration of PnET Succession in an European context. No north america species, though.
#
# - For Quebec,
#     - **(2)** Data from [Mina et al. 2021](https://esajournals.onlinelibrary.wiley.com/doi/10.1002/eap.2221) (also used in [Mina et al. 2022](https://onlinelibrary.wiley.com/doi/abs/10.1111/gcb.16197)). All parameters used are on [this Github repository](https://github.com/mrcmina/REDEFINE-Mina_etal_EcolAppl/tree/1.0/Input_Data/PnET). ⚠️ These parameters are for PnET Succession 3.5. According to [Gustafson and Miranda (2023)](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf), several parameters (not precised) need recalibration after version 5.0; therefore, these parameters cannot be used "as is" with v.5.1, even though they are for Quebec.
#     - **(3)** Data from [Ameray et al. 2023](https://www.frontiersin.org/articles/10.3389/ffgc.2023.1020305). All parameters used are on [this Github repository](https://github.com/Ameray/PhD-thesis/tree/main). ⚠️ These parameters are for PnET Succession 4.1. According to [Gustafson and Miranda (2023)](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf), several parameters (not precised) need recalibration after version 5.0; therefore, these parameters cannot be used "as is" with v.5.1, even though they are for Quebec.
#
# For the core species parameters (life history traits), here are some additional sources :
#
# - [The Sylvic manual of Burns and Honkala](https://www.srs.fs.usda.gov/pubs/misc/ag_654/table_of_contents.htm) (US department of agriculture) : used by almost every LANDIS-II studies in north america. Contains a lot of information that allow you to estimate the parameters.
#
# :::{warning} Change in core species parameters between LANDIS-II v7 and LANDIS-II v8
# The v7 of LANDIS-II has been used by a lot of studies in North America; but with the recent (2025-2026) switch to the version 8 of the model, the core species parameters have been changed : shade tolerance and fire tolerance have been removed, the vegetative reproduction is no longer a "yes/no" but a probability and you must indicate the sprouting ages, etc.
#
# So if you take a look at previous studies with LANDIS-II, you will most likely find the old format of parameters, and you might need to do a bit more research to find the new ones.
# :::
#
# :::{tip} What do I do if I can't find published parameters for a given tree species ? Where do I find initial parameter values ?
# This is the though part. The big problem with the PnET models (as explanation in the user guide) is that they are described as models easy to parameterize because you can just use empirical values as parameters; but strangely, it's extremely hard to find empirical values for the parameters used in the model, even just the most important ones !
#
# So you might find yourself without any good source of parameters for a species you want to calibrate. If you find yourself in this kind of situation, **there is a section at the end of this notebook that will allow you to generate the parameters for a tree species based on its shade tolerance score (from 1 to 5) and its evergreen/deciduous type**. This is done using the advice of Eric Gustafson in the PnET-Succession user guide; it's far from perfect, but it should produce a parameter set that makes sense.
#
# However, you will still need estimates of the growth curve in ideal conditions (see next notebook) and longevity data to be able to calibrate your species. And if you can find parameters or empirical values for the parameters in the litterature, you should try to do so.
# :::

# %% [markdown]
# :::{warning} Format of the following tables of parameters
#
# As the end of this notebook is a code section that will read the following tables of parameters and transform them in Python dictionnaries that can be used by the functions of `functionsForCalibration.py` to create LANDIS-II parameter files, which will be used to automatize LANDIS-II simulations further on.
#
# So that the function can read the tables properly, the content of each cell must respect the following format :
# - The cell must start with the value of the parameter
# - All other content must be either in footnote format (between square brackets `[]`), between parenthesis, or after an asterisk. This content will then be ignored by the function to just keep the value at the beginning of the cell.
#
# Example :
# - `0.35 (average among species in [^2] and [^3])` : Good. Only the value `0.35` will be taken; the rest, between parenthesis, will be ignored.
# - `0.35 : average among species in [^2] and [^3]` : Not good. The rest of the cell appart from the value (`0.35`) should be between parenthesis or square brackets.
# :::

# %% [markdown]
# ## List of your species (full latin names and codes you will be using)
#
# Before we start, to keep track of things, but also so that we are able to gather parameter values and targets in future code section, **indicate in the following code cell the code used for your species in your simulations (e.g. `ABIE.BAL`) and the corresponding full latin name for the species (e.g. *Abies balsamea*)**.
#
# The code section will put the associations in a .json file that will be re-used in the following code cells when needed.
#
# In these notebooks (which serve as a proof-of-concept), I am calibrating 6 species in total that are common to the study area of Manawan in Quebec (see Notebook 0.2 for more information). Here, I indicate the three species for which I will derive parameters from the litterature; the other three species will be defined in later code cells to test the functions that are made to derive the initial parameters automatically (see sections bellow).

# %%
import json

# Indicate your species code : species latin full name in this python dictionnary.
speciesNamesDictionnary = {
    "ABIE.BAL":"Abies balsamea",
    "ACER.RUB":"Acer rubrum",
    "PICE.MAR":"Picea mariana"
}

with open("./SpeciesParametersSets/speciesNamesDictionnary.json", "w") as f: json.dump(speciesNamesDictionnary, f)

# %% [markdown]
# ## Core species parameters for the species

# %% [markdown]
# These parameters are needed by all LANDIS-II extensions. They will not be calibrated, as they are all species life-history traits that should be found in the litterature.
#
# :::{tip} If you have trouble finding these parameters for one of your species
# It can be difficult to find values for these, especially because some of them changed with LANDIS-II v8. Here are a couple of sources I recommend :
#
# Longevity : [Loehle and al (1988)](https://cdnsciencepub.com/doi/10.1139/x88-032) or [TRY database trait number 59 (Plant lifespan)](https://www.try-db.org/de/TraitSearch.php). But you'll need to distinguish typical and maximum longevity anyway later in these notebooks; see Notebook 4 and notebook 6.
#
# Age of sexual maturity : [TRY database trait number 155 (Plant ontogeny: age of maturity)](https://www.try-db.org/de/TraitSearch.php)
#
# Seed Dispersal distance : [TRY database trait number 193 (Dispersal distance)](https://www.try-db.org/de/TraitSearch.php)
#
# A source often used for most core parameters in LANDIS-II : [Burns and Honkala (1990)](https://www.srs.fs.usda.gov/pubs/misc/ag_654/table_of_contents.htm). You can use a tool like NotebookLM (AI tool from Google that can read through large documents) and give it the pdf for a quick search, and a quick estimate of the parameters you need.
#
# There is a similar handbook for tree species of British Columbia (Canada) that I wasn't able to procure, but is said to be similar to the handbooks of Burns and Honkala : [Karel et al. (1999)](https://open.library.ubc.ca/soa/cIRcle/collections/facultyresearchandpublications/52383/items/1.0107280). Some of the information of the book can be found [on this web page of the BC government](https://www2.gov.bc.ca/gov/content/industry/forestry/managing-our-forest-resources/silviculture/stocking-standards/tree-species-compendium-index).
#
# Another website with lots of information : [https://plants.sc.egov.usda.gov/](https://plants.sc.egov.usda.gov/)
# :::
#
# :::{warning} Be sure to indicate the core parameter for all the species you will use
# At the end of this notebook, you will find a code cell to generate new species parameters for PnET-Succession (for species for which you cannot find published PnET-Succession parameter values). For each of these additional species, be sure to indicate their core species parameters here. **The code cell at the end of the notebook will only generate parameters for PnET-Succession, and not these core species parameters**. I haven't found a way to derive/generate core species parameters easily/with a script from the literature, as I haven't found any database that would allow me to do so.
# :::
#
# Exponents in the following table are the sources with the same numbers as noted in [Sources of parameter values](source_param_values).
#
# <!--
# WARNING : If you edit this table, always put any commentaries following the value of the parameter inside parenthesis. This is because we use some Python functions later to read this markdown cell and extract all of the parameter values from this table, to put it into a Python dictionnary that we can then use to interact with LANDIS-II scenarios. Parenthesis and square brackets are ignored, which help the function get the right values for the parameters.
#
# Also, always separate the value from parenthesis or square brackets with a space
#
# In short, don't do :
# 7[^1]
# 7, comes from this source
# 7; comes from this source
#
# Do :
# 7 [^1]
# 7 (Comes from this source)
# 7 (because of this reason) [^1]
#
# Also : Here, the name of the columns must be the exact same as write_LANDIS_SpeciesCoreFile in functionsForCalibration.py.
#
# UPDATE : Shade tolerance and fire tolerance have both been removed with the switch to LANDIS-II v8, as they are not used as core parameters anymore
# -->
#
# | Species Name | Longevity | Sexual Maturity | Seed Dispersal Distance - Effective | Seed Dispersal Distance - Maximum | Vegetative Reproduction Probability | Sprout Age - Min | Sprout Age - Max | Post Fire Regen |
# |:-----------:|:------------:|:------------:|:-----------:|:------:|:------:|:------:|:------:|:------:|
# | *Abies balsamea* | 200 [^2] | 25 [^2] | 30 [^2] | 160 [^2] | 0 [^2] | 0 [^2] | 0 [^2]  | none [^2] |
# | *Acer rubrum* | 235 [^2] | 5 [^2] | 100 [^2] | 200 [^2] | 0.75 [^2] | 0 [^2] | 150 [^2] | none |
# | *Picea mariana* | 215 [^2] | 30 [^2] | 79 [^2]  | 158 [^2] | 0 [^2] | 0 [^2] | 0 [^2] | none |
# | *Acer saccharum* | 300 [^2] | 40 [^2] | 100 [^2]  | 200 [^2] | 0.1 [^2] | 0 [^2] | 60 [^2] | none |
# | *Larix laricina* | 180 [^2] | 35 [^2] | 100 [^2]  | 400 [^2] | 0.5 [^2] | 0 [^2] | 0 [^2] | none |
# | *Populus tremuloides* | 110 [^2] | 20 [^2] | 1000 [^2]  | 5000 [^2] | 0.9 [^2] | 0 [^2] | 100 [^2] | none |
#
# [^1]: [Gustafson and Miranda (2023)](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf)
# [^2]: [Mina et al. 2021](https://esajournals.onlinelibrary.wiley.com/doi/10.1002/eap.2221) : [Github repo](https://github.com/mrcmina/REDEFINE-Mina_etal_EcolAppl/tree/1.0/Input_Data/PnET)
# [^3]: [Ameray et al. 2023](https://www.frontiersin.org/articles/10.3389/ffgc.2023.1020305) : [Github repo](https://github.com/Ameray/PhD-thesis/tree/main/chapter2/MU2)
# [^4]: [Aber et al. (1996)](https://link.springer.com/article/10.1007/BF00328606)
# [^5]: [Aber et al. 1995, Table 2](https://www.int-res.com/articles/cr/5/c005p207.pdf)
# [^6]: [Ollinger and Smith 2005, Table 1](https://link.springer.com/article/10.1007/s10021-005-0079-5)
# [^7]: [Smith et al. 2006](https://books.google.ca/books?hl=fr&lr=&id=rNMHmlNynNsC&oi=fnd&pg=PP4&dq=Smith,+J.E.,+Heath,+L.S.,+Skog,+K.E.,+Birdsey,+R.A.+2006.+Methods+for+calculating+forest+ecosystem+and+harvested+carbon+with+standard+estimates+for+forest+types+of+the+United+States.+USDA+Forest+Service+General+Technical+Report+NE-343.+Northeastern+Research+Station,+Newtown+Square,+PA,+USA.+216+p.&ots=Urs7Cs4FtB&sig=zS2t0mlM9OAMVnifokfRNYAUnpk#v=onepage&q&f=false)
# [^8]: [Suárez-Muñoz1 et al. 2021](https://www.frontiersin.org/journals/ecology-and-evolution/articles/10.3389/fevo.2021.653393/full)

# %% [markdown]
# ## Initial generic parameters for the species

# %% [markdown]
# Here is a table of species parameter values for the parameters that will be kept as generic (MaintResp, InitialNSC, FracBelowG, PsnAgeRed, DNSC, DVPD1, DVPD2, BFolResp, Q10, FolLignin, CFracBiomass) between species.
#
# Exponents are the sources with the same numbers as noted in [Sources of parameter values](source_param_values).
#
# <!--
# WARNING : If you edit this table, always put any commentaries following the value of the parameter inside parenthesis. This is because we use some Python functions later to read this markdown cell and extract all of the parameter values from this table, to put it into a Python dictionnary that we can then use to interact with LANDIS-II scenarios. Parenthesis and square brackets are ignored, which help the function get the right values for the parameters.
#
# Also, always separate the value from parenthesis or square brackets with a space
#
# In short, don't do :
# 7[^1]
# 7, comes from this source
# 7; comes from this source
#
# Do :
# 7 [^1]
# 7 (Comes from this source)
# 7 (because of this reason) [^1]
# -->
#
# | MaintResp | InitialNSC | FracBelowG | PsnAgeRed | DNSC | DVPD1 | DVPD2 | BFolResp | Q10 | FolLignin | IMAX |
# |:-----------:|:------------:|:------------:|:-----------:|:------:|:------:|:------:|:------:|:------:|:------:|:------:|
# | 0.012 [^17] | 7 [^11] | 0.35 (average among species in [^10] and [^11]) | 5 [^9] | 0.05 [^9] | 0.05 [^9] | 2 [^9] | 0.1 [^9] | 2 [^9] | 0.2 [^9] | 5 [^9] |
#
# [^9]: [Gustafson and Miranda (2023)](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf)
# [^10]: [Mina et al. 2021](https://esajournals.onlinelibrary.wiley.com/doi/10.1002/eap.2221) : [Github repo](https://github.com/mrcmina/REDEFINE-Mina_etal_EcolAppl/tree/1.0/Input_Data/PnET)
# [^11]: [Ameray et al. 2023](https://www.frontiersin.org/articles/10.3389/ffgc.2023.1020305) : [Github repo](https://github.com/Ameray/PhD-thesis/tree/main/chapter2/MU2)
# [^12]: [Aber et al. (1996)](https://link.springer.com/article/10.1007/BF00328606)
# [^13]: [Aber et al. 1995, Table 2](https://www.int-res.com/articles/cr/5/c005p207.pdf)
# [^14]: [Ollinger and Smith 2005, Table 1](https://link.springer.com/article/10.1007/s10021-005-0079-5)
# [^15]: [Smith et al. 2006](https://books.google.ca/books?hl=fr&lr=&id=rNMHmlNynNsC&oi=fnd&pg=PP4&dq=Smith,+J.E.,+Heath,+L.S.,+Skog,+K.E.,+Birdsey,+R.A.+2006.+Methods+for+calculating+forest+ecosystem+and+harvested+carbon+with+standard+estimates+for+forest+types+of+the+United+States.+USDA+Forest+Service+General+Technical+Report+NE-343.+Northeastern+Research+Station,+Newtown+Square,+PA,+USA.+216+p.&ots=Urs7Cs4FtB&sig=zS2t0mlM9OAMVnifokfRNYAUnpk#v=onepage&q&f=false)
# [^16]: [Suárez-Muñoz1 et al. 2021](https://www.frontiersin.org/journals/ecology-and-evolution/articles/10.3389/fevo.2021.653393/full)
# [^17]: The value proposed by [Gustafson and Miranda (2023)](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf) is 0.002. I propose to increase it a lot because during the first calibration step, I noticed that almost all species produced "Too much biomass" compared to the biomass peak targets of the NFI (see notebook 4). This might be due to the fact that other researchers tend to calibrate based on biomass peaks that are much higher, often coming from sample plot data where extremes are more present than in NFI data.

# %% [markdown]
# ## Initial species parameters

# %% [markdown]
# Here is a table of initial values (values we will start with for the calibration) for the parameters that will vary among species (FolN, SLWmax, TOFol, TORoot, TOWood, HalfSat, H1, H2, H3, H4, LeafOnMinT, PsnTMin, PsnTOpt, 20k, EstMoist, EstRad, FracFol, FrActWd, SLWDel, k, KWdLit, AmaxA and AmaxB).
#
# Exponents are the sources with the same numbers as noted in [Sources of parameter values](source_param_values).
#
# :::{important}
# As per [Gustafson and Miranda (2023)](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf) : "It is more important to set FolN to represent photosynthetic capacity relative to other species than to match empirical observations (because the model uses FolN as a proxy for photosynthetic capacity).".
# :::
#
# <!--
# WARNING : If you edit this table, always put any commentaries following the value of the parameter inside parenthesis. This is because we use some Python functions later to read this markdown cell and extract all of the parameter values from this table, to put it into a Python dictionnary that we can then use to interact with LANDIS-II scenarios. Parenthesis and square brackets are ignored, which help the function get the right values for the parameters.
#
# Also, always separate the value from parenthesis or square brackets with a space
#
# In short, don't do :
# 7[^1]
# 7, comes from this source
# 7; comes from this source
#
# Do :
# 7 [^1]
# 7 (Comes from this source)
# 7 (because of this reason) [^1]
# -->
#
# | Species | FolN | SLWmax  | TOFol | TORoot | TOWood | HalfSat | H1 | H2 | H3 | H4 | LeafOnMinT | PsnTMin | PsnTOpt | k | EstMoist | EstRad | FracFol | FrActWd | SLWDel | AmaxA | AmaxB | KWdLit | CFracBiomass | MaxFracFol | FracFolShape |
# |:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|
# | *Abies balsamea* | 1.3 [^18] (increased to provide boost with the increased MaintResp) | 145 [^18] | 0.2 [^18] | 0.03 [^18] (same as TOWood) | 0.03 [^18] | 134 [^18] | -1.5 [^18] | 3 [^18] | 140 [^18] | 140 [^18] | 1.9 [^18] | 0.8 [^18] | 16.8 [^18] | 0.5 [^18] | 1 [^18] (recommanded in paragraph 26 and 32 of calibration tips) | 0.976 (from page 74 of [^18], based on the fact that *Abies balsamea* is very shade tolerant) | 0.07 [^18] | 0.00003 [^18] | 0.0 [^18] | 5.3 [^18] | 21.5 [^18] | 0.125 (written as "KWlit" because of typo in [^18]) [^18]  | 0.5 (from page 74 of [^18], based on the fact that *Abies balsamea* is very shade tolerant) | 0.07 [^26] | 6 [^27] |
# | *Acer rubrum* | 2.35 [^18] (But decreased as it was growing too much) | 73 [^18] | 1 [^18] | 0.037 [^18] (same as TOWood) | 0.037 [^18]  | 181 [^18] | -2 [^18] | 2 [^18] | 145 [^18] | 145 [^18] | 2.4 [^18] | 1.75 [^18] | 25.5 [^18] | 0.58 [^18] | 1 [^18] (recommanded in paragraph 26 and 32 of calibration tips) | 0.928 (from page 74 of [^18], based on the fact that *Acer rubrum* is somewhat shade tolerant) | 0.014 [^18] | 0.000022 [^18] | 0.2 [^18] | -46 [^18] | 71.9 [^18] | 0.075 (written as "KWlit" because of typo in [^18]) [^18] | 0.45 (from page 74 of [^18], based on the fact that *Acer rubrum* is somewhat shade tolerant) | 0.014 [^26] | 6 [^27]  |
# | *Picea mariana* | 1.5 [^18] (increased to provide boost with the increased MaintResp) | 225 [^18] | 0.18 [^18] | 0.03 [^18] (same as TOWood) | 0.03 [^18] | 197 [^18] | -4.5 [^18] | 1.5 [^18] | 138 [^18] | 138 [^18] | 1.5 [^18] | 0.175 [^18] | 15.1 [^18] | 0.5 [^18] | 1 [^18] (recommanded in paragraph 26 and 32 of calibration tips) | 0.954 (from page 74 of [^18], based on the fact that *Picea mariana* is pretty shade tolerant) | 0.04 [^18] | 0.000022 [^18] | 0.0 | 5.3 [^18] | 21.5 [^18] | 0.125 (written as "KWlit" because of typo in [^18]) [^18] | 0.475 (from page 74 of [^18], based on the fact that *Picea mariana* is pretty shade tolerant) | 0.04 [^26] | 6 [^27] |
#
# [^18]: [Gustafson and Miranda (2023)](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf)
# [^19]: [Mina et al. 2021](https://esajournals.onlinelibrary.wiley.com/doi/10.1002/eap.2221) : [Github repo](https://github.com/mrcmina/REDEFINE-Mina_etal_EcolAppl/tree/1.0/Input_Data/PnET)
# [^20]: [Ameray et al. 2023](https://www.frontiersin.org/articles/10.3389/ffgc.2023.1020305) : [Github repo](https://github.com/Ameray/PhD-thesis/tree/main/chapter2/MU2)
# [^21]: [Aber et al. (1996)](https://link.springer.com/article/10.1007/BF00328606)
# [^22]: [Aber et al. 1995, Table 2](https://www.int-res.com/articles/cr/5/c005p207.pdf)
# [^23]: [Ollinger and Smith 2005, Table 1](https://link.springer.com/article/10.1007/s10021-005-0079-5)
# [^24]: [Smith et al. 2006](https://books.google.ca/books?hl=fr&lr=&id=rNMHmlNynNsC&oi=fnd&pg=PP4&dq=Smith,+J.E.,+Heath,+L.S.,+Skog,+K.E.,+Birdsey,+R.A.+2006.+Methods+for+calculating+forest+ecosystem+and+harvested+carbon+with+standard+estimates+for+forest+types+of+the+United+States.+USDA+Forest+Service+General+Technical+Report+NE-343.+Northeastern+Research+Station,+Newtown+Square,+PA,+USA.+216+p.&ots=Urs7Cs4FtB&sig=zS2t0mlM9OAMVnifokfRNYAUnpk#v=onepage&q&f=false)
# [^25]: [Suárez-Muñoz1 et al. 2021](https://www.frontiersin.org/journals/ecology-and-evolution/articles/10.3389/fevo.2021.653393/full)
# [^26]: Recommended by [Gustafson and Miranda (2023)](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf) to set it as equal to FracFol to start (see table 1 of calibration tips).
# [^27]: Recommended by [Gustafson and Miranda (2023)](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf) to set it equal to 6 to begin the calibration : *Adjust the initial part of the growth curve (especially if the species has rapid initial growth) using MaxFracFol and FracFolShape (6 is a good starting value).*.
# [^29]: Lower FolN than recommended in some source because the species always made too much biomass in the calibration.

# %% [markdown]
# ## Generic parameters

# %% [markdown]
# These remaining parameters are the one that must be specified in the generic parameter file no matter what, but that are not supposed to vary by species or by ecoregion (PARunits, PrecipEvents, PrecipEventsWithReplacement, ETExtCoeff, RETCropCoeff, PreventEstablishment, Wythers, DTEMP, MaxPest, AmaxFrac.
#
# Exponents are the sources with the same numbers as noted in [Sources of parameter values](source_param_values).
#
# <!--
# WARNING : If you edit this table, always put any commentaries following the value of the parameter inside parenthesis. This is because we use some Python functions later to read this markdown cell and extract all of the parameter values from this table, to put it into a Python dictionnary that we can then use to interact with LANDIS-II scenarios. Parenthesis and square brackets are ignored, which help the function get the right values for the parameters.
#
# Also, always separate the value from parenthesis or square brackets with a space
#
# In short, don't do :
# 7[^1]
# 7, comes from this source
# 7; comes from this source
#
# Do :
# 7 [^1]
# 7 (Comes from this source)
# 7 (because of this reason) [^1]
# -->
#
# | PARunits | PrecipEvents | PrecipEventsWithReplacement | ETExtCoeff | RETCropCoeff | PreventEstablishment | Wythers | DTEMP | MaxPest | AmaxFrac | LayerThreshRatio |
# |:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|
# | umol (Same unit as Halfsat, which is from [^30], see previous cell; umol indicates umol/m2/seconds) | 11 [^30] | True (default value in [^30]) | 0.65 (default value in [^30]) | 0.30 (default value in [^30]) | True (to prevent establishment in the monoculture calibration) | True [^30] | True [^30] | 1.0 (from [^30], where it's proposed that MaxPest = timestep length/10. Not useful until the calibration of establishment.) | 0.75 (default value in [^30]) | 0.67 ([^30], see warning below) |
#
# [^30]: [Gustafson and Miranda (2023)](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf)
# [^31]: [Mina et al. 2021](https://esajournals.onlinelibrary.wiley.com/doi/10.1002/eap.2221) : [Github repo](https://github.com/mrcmina/REDEFINE-Mina_etal_EcolAppl/tree/1.0/Input_Data/PnET)
# [^32]: [Ameray et al. 2023](https://www.frontiersin.org/articles/10.3389/ffgc.2023.1020305) : [Github repo](https://github.com/Ameray/PhD-thesis/tree/main/chapter2/MU2)
# [^33]: [Aber et al. (1996)](https://link.springer.com/article/10.1007/BF00328606)
# [^34]: [Aber et al. 1995, Table 2](https://www.int-res.com/articles/cr/5/c005p207.pdf)
# [^35]: [Ollinger and Smith 2005, Table 1](https://link.springer.com/article/10.1007/s10021-005-0079-5)
# [^36]: [Smith et al. 2006](https://books.google.ca/books?hl=fr&lr=&id=rNMHmlNynNsC&oi=fnd&pg=PP4&dq=Smith,+J.E.,+Heath,+L.S.,+Skog,+K.E.,+Birdsey,+R.A.+2006.+Methods+for+calculating+forest+ecosystem+and+harvested+carbon+with+standard+estimates+for+forest+types+of+the+United+States.+USDA+Forest+Service+General+Technical+Report+NE-343.+Northeastern+Research+Station,+Newtown+Square,+PA,+USA.+216+p.&ots=Urs7Cs4FtB&sig=zS2t0mlM9OAMVnifokfRNYAUnpk#v=onepage&q&f=false)
# [^37]: [Suárez-Muñoz1 et al. 2021](https://www.frontiersin.org/journals/ecology-and-evolution/articles/10.3389/fevo.2021.653393/full)

# %% [markdown]
# :::{warning} About the LayerThreshRatio parameter
# LayerThreshRatio is a generic parameter that is used to define how easily age cohorts of the same species are grouped in the same canopy layer.
#
# I'm still having trouble wrapping my mind about how the parameter works exactly; what's certain is that it has a large effect on the outcomes of simulations. Increasing it seems to let more cohorts cohabitate together in a cell, especially young and old cohorts. Might be because in this case, young cohorts tend to be grouped with older cohorts more easily, and they thus receive more light according to the algorithm.
#
# It's difficult for me to recommend the right value for this parameter. For now, I will put it at 0.67, as it's one of the values recommanded by [Eric Gustafson in the user guide](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf), and because it seems to allow more room for complex dynamics inside the cells rather than a periodic domination by large, old cohorts. But you might want to change it if you're seeing strange results of cohabitations between cohort in a given cell.
# :::

# %% [markdown]
# ## Exporting initial parameters tables into JSON files
#
# These .JSON files will simply contain the values of the tables above, and will be used to quickly launch LANDIS-II simulations with these parameters without doing it by hand (see next notebooks).
#
# **You can use the code sections after this one to add more species to the core species parameter .json file and PnET-Succession species parameter .json file; as such, the files created by this code section are not final, and can be edited with addition in the following sections.**

# %%
from functionsForCalibration import *
import json

# We read the markdown content of the previous cell that contains the markdown table with the parameters,
# and we transform it into a Python dictionnary that can be used with the other functions to interact with
# LANDIS-II scenarios.

# Reading species core parameters
# We add the Landis Data parameter indication
coreSpeciesParameters = dict()
coreSpeciesParameters['LandisData'] = 'Species'
markdownText = read_markdown_cell("./3.Initial_Species_Parameters.ipynb", 12)
markdownTable = extract_table(markdownText)
coreSpeciesParameters.update(parseTableSpeciesParameters(markdownTable))

# print(coreSpeciesParameters)

# Reading PnET Species Parameters
# We format the dictionnary for use with the other functions
PnETSpeciesParametersFinal = dict()
PnETSpeciesParametersFinal ['LandisData'] = 'PnETSpeciesParameters'
markdownText = read_markdown_cell("./3.Initial_Species_Parameters.ipynb", 16)
markdownTable = extract_table(markdownText)
PnETSpeciesParameters = parseTableSpeciesParameters(markdownTable)
PnETSpeciesParametersFinal['PnETSpeciesParameters'] = PnETSpeciesParameters

# print(PnETSpeciesParametersFinal)

# Species generic parameters
# We add the Landis Data parameter indicator and another needed for this parameter file
genericParameters = dict()
genericParameters['LandisData'] = 'PnETGenericParameters'
genericParameters['PnETGenericParameters'] = 'Value'
markdownText = read_markdown_cell("./3.Initial_Species_Parameters.ipynb", 14)
markdownTable = extract_table(markdownText)
genericParameters.update(parseTableGenericParameters(markdownTable))

# print(genericParameters)

# Generic parameters
# We're going to add these to the generic species parameters to be in one single dict to create the parameter file that corresponds to them
markdownText = read_markdown_cell("./3.Initial_Species_Parameters.ipynb", 18)
markdownTable = extract_table(markdownText)
genericParameters.update(parseTableGenericParameters(markdownTable))
# print(genericParameters)

# Now, we change any mention of the species name toward your species codes
# using the equivalence dictionnary create earlier
with open("./SpeciesParametersSets/speciesNamesDictionnary.json", 'r') as file:
    speciesCodeDict = json.load(file) 

for key in speciesCodeDict.keys():
    # print(key)
    # print(speciesCodeDict[key])
    coreSpeciesParameters = replace_in_dict(coreSpeciesParameters, speciesCodeDict[key], key)
    PnETSpeciesParametersFinal = replace_in_dict(PnETSpeciesParametersFinal, speciesCodeDict[key], key)

# We print the dictionnaries for verification
print(coreSpeciesParameters)
print(PnETSpeciesParametersFinal)
print(genericParameters)

# We save the dictionnary in a file to use it later in other notebooks.
with open('./SpeciesParametersSets/Initial/coreSpeciesParameters.json', 'w') as json_file:
    # Step 4: Write the dictionary to the file
    json.dump(coreSpeciesParameters, json_file)
with open('./SpeciesParametersSets/Initial/PnETSpeciesParameters.json', 'w') as json_file:
    # Step 4: Write the dictionary to the file
    json.dump(PnETSpeciesParametersFinal, json_file)
with open('./SpeciesParametersSets/Initial/genericParameters.json', 'w') as json_file:
    # Step 4: Write the dictionary to the file
    json.dump(genericParameters, json_file)
# Out:
# {'LandisData': 'Species', 'ABIE.BAL': {'Longevity': '200', 'Sexual Maturity': '25', 'Seed Dispersal Distance - Effective': '30', 'Seed Dispersal Distance - Maximum': '160', 'Vegetative Reproduction Probability': '0', 'Sprout Age - Min': '0', 'Sprout Age - Max': '0', 'Post Fire Regen': 'none'}, 'ACER.RUB': {'Longevity': '235', 'Sexual Maturity': '5', 'Seed Dispersal Distance - Effective': '100', 'Seed Dispersal Distance - Maximum': '200', 'Vegetative Reproduction Probability': '0.75', 'Sprout Age - Min': '0', 'Sprout Age - Max': '150', 'Post Fire Regen': 'none'}, 'PICE.MAR': {'Longevity': '215', 'Sexual Maturity': '30', 'Seed Dispersal Distance - Effective': '79', 'Seed Dispersal Distance - Maximum': '158', 'Vegetative Reproduction Probability': '0', 'Sprout Age - Min': '0', 'Sprout Age - Max': '0', 'Post Fire Regen': 'none'}, 'Acer saccharum': {'Longevity': '300', 'Sexual Maturity': '40', 'Seed Dispersal Distance - Effective': '100', 'Seed Dispersal Distance - Maximum': '200', 'Veget
# ...

# %% [markdown]
# ## Getting drought and waterlogging tolerance parameter values from the litterature using regression
#
# In PnET-Succession, 4 parameters are related to the effect of water in the soils on tree growth : H1, H2, H3 and H4.
#
# These parameters together define a curve relating the pressure head in the soil with the value of fWater, which is the photosynthesis reduction factor linked to water. Here is an example from the user guide :
#
# ![image.png](attachment:1c852e95-a961-420c-b47a-99821eac45ad.png)
#
# The idea of the trapezoid is that the photosynthesis of tree is overall very little affect by the amount of water present in the soil (fWater = 1, no effect on the photosynthesis); unless we arrive at thresholds of waterlogging or drought (pressure head too small or too high) where the photosynthesis will abruptly diminish. The user guide even recommends to use a value of H3 and H4 (the parameters related to high values of pressure head = drought conditions) to be the same, so that photosynthesis simply stops in drought months.
#
# :::{warning}
# Be careful about the signs (positive or negative) used for the pressure head ! I've had a lot of confusion about this.
#
# The pressure head is a measure of water pressure in the soil. It represents the following idea : If I put a cylinder in contact with the soil, will it be filled with water because there is so much water in the soil that it wants to get out (pressure, which happens during waterlogging); or will the soil instead "suck" water because it's lacking water (suction, which happens during droughts) ?
#
# The problem is that normally, a suction normally results in negative values of pressure head (if I had water in my cylinder, the water would go down in the soils); while pressure results in positive values (if the water pushes up into the cylinder because of pressure, how much does it pushes up ?). Pressure head is therefore the measurement, in units of distance, of how up or down the water goes when put in contact with the soil.
#
# But in PnET-Succession, the sign convention is reversed by using the "absolute" values of pressure head. What that means is that in the case of PnET-Succession, the higher the pressure head, the more we are in drought; and vice versa. As such, the drought parameters H3 and H4 often have positive values above 100; while the waterlogging parameters H1 and H3 are often near 0, or even negative. Keep that in mind !
# :::
#
# We sadly lack empirical data to get good estimates of these 4 parameters, and even more for many species. Although [Gustafson et al. 2025](https://bg.copernicus.org/articles/22/2499/2025/) tried to use empirical/experimental data to derive values of H1 and H2 (waterlogging).
#
# As such, ideally, we would calibrate this parameters to ensure that the tree species react in the right way on the right soils in the landscape.
#
# Sadly, I haven't found a way to do this calibration properly, and I'm lacking time. As such, I went with a simpler option :
#
# We can simply create a regression (linear or non-linear) of the score of Drought and Waterlogging tolerance acquired from [Niinemets and Valladares 2006](https://onlinelibrary.wiley.com/doi/abs/10.1890/0012-9615%282006%29076%5B0521%3ATTSDAW%5D2.0.CO%3B2) and previously published parameters (i.e. those the [user guide of PnET-Succession](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf), including those of [Gustafson et al. 2025](https://bg.copernicus.org/articles/22/2499/2025/) which have been derived from an empiical experiment. This is quick and easy, and will make sure that we use parameters similar to previous studies.
#
# The default of this approach is that we don't do any calibration, and just re-use what have been done before. It's also deeply reliant on the hypothesis that these parameters are completely dependent on a measure as fuzzy as the "drought tolerance" or "waterlogging tolerance" of a give tree species. It also will not produce parameters that are in any way contextual to our landscape (soils, precipitations, water in the soils); we just have to hope that the model will produce soil water content that make sense for our landscape (although this can be explored).
#
# Still, I believe that this will do for now.
#
# **The following code section will retrieve the drought and waterlogging tolerance scores from [Niinemets and Valladares 2006](https://onlinelibrary.wiley.com/doi/abs/10.1890/0012-9615%282006%29076%5B0521%3ATTSDAW%5D2.0.CO%3B2) for your species (using their full latin names indicated in a previous section in this notebook) and then use a Generalized Additive Model based on published data to interpolate the parameter values of H1, H2, H3 and H4.**
#
# :::{warning} Do not run the following code cell if you want to keep your H1, H2, H3 and H4 parameters values as indicated in the tables above !
# Running this code cell will replace the values of H1, H2, H3 and H4 that you might have indicated in the table above with new values derived from this approach.
#
# Unless you have faith in the values you have indicated, I would recommend running the cell, because this approach (using the drought and waterlogging tolerance scores of [Niinemets and Valladares 2006](https://onlinelibrary.wiley.com/doi/abs/10.1890/0012-9615%282006%29076%5B0521%3ATTSDAW%5D2.0.CO%3B2)) will ensure that your species have values of H1, H2, H3 and H4 that rank them relative to each other in terms of drought and waterlogging tolerance.
# :::

# %%
from functionsForCalibration import *
import json
import pandas as pd

with open("./SpeciesParametersSets/speciesNamesDictionnary.json", "r") as file: speciesNamesDictionnary = json.load(file)

niinemetsValladaresData = pd.read_csv("./ReferencesAndData/Others/NiinemetsEtValladares_AppendixTable_full.csv")

resultDict = {}
for speciesName in speciesNamesDictionnary:

    print(f"Computing drought and waterlogging parameters for {speciesName}")
    # Getting drought and wl tolerance from NiinemetsAndValladares
    if speciesNamesDictionnary[speciesName] not in list(niinemetsValladaresData["Species"]):
        print("Species " + str(speciesNamesDictionnary[speciesName]) + " is not found in the data of Niinemets and Valladares (2006). Please enter the information of the species manually :")
        drought_tolerance = -999
        while drought_tolerance < 1 or drought_tolerance > 5:
            drought_tolerance = input("Please input the drought tolerance of " + str(speciesNamesDictionnary[speciesName]) + " (from 1 = very intolerant to 5 = very tolerant")
        waterlogging_tolerance = -999
        while waterlogging_tolerance < 1 or waterlogging_tolerance > 5:
            waterlogging_tolerance = input("Please input the waterlogging tolerance of " + str(speciesNamesDictionnary[speciesName]) + " (from 1 = very intolerant to 5 = very tolerant")
    else:
        rowWithSpecies = niinemetsValladaresData[niinemetsValladaresData["Species"] == speciesNamesDictionnary[speciesName]]
        drought_tolerance = list(rowWithSpecies["Drought tolerance"])[0]
        waterlogging_tolerance = list(rowWithSpecies["Waterlogging tolerance"])[0]
    
    resultDict[speciesName] = predict_H_parameters(
    drought_tolerance=drought_tolerance,
    waterlogging_tolerance=waterlogging_tolerance,
    plot=False,
    gam_summary=False
    )

print(resultDict)
    
# Re-writing parameter dicts
DictOfCoreSpeciesParameters = json.load(open('./SpeciesParametersSets/Initial/coreSpeciesParameters.json'))
DictOfPnETSpeciesParameters = json.load(open('./SpeciesParametersSets/Initial/PnETSpeciesParameters.json'))
DictOfPnETGenericParameters = json.load(open('./SpeciesParametersSets/Initial/genericParameters.json'))

for species in resultDict:
    if species not in DictOfPnETSpeciesParameters["PnETSpeciesParameters"].keys():
        DictOfPnETSpeciesParameters["PnETSpeciesParameters"][species] = dict()
    DictOfPnETSpeciesParameters["PnETSpeciesParameters"][species]["H1"] = str(round(resultDict[species]["H1"],2))
    DictOfPnETSpeciesParameters["PnETSpeciesParameters"][species]["H2"] = str(round(resultDict[species]["H2"],2))
    DictOfPnETSpeciesParameters["PnETSpeciesParameters"][species]["H3"] = str(round(resultDict[species]["H3"],2))
    DictOfPnETSpeciesParameters["PnETSpeciesParameters"][species]["H4"] = str(round(resultDict[species]["H4"],2))

with open("./SpeciesParametersSets/Initial/coreSpeciesParameters.json", "w") as f: json.dump(DictOfCoreSpeciesParameters, f)
with open("./SpeciesParametersSets/Initial/PnETSpeciesParameters.json", "w") as f: json.dump(DictOfPnETSpeciesParameters, f)
with open("./SpeciesParametersSets/Initial/genericParameters.json", "w") as f: json.dump(DictOfPnETGenericParameters, f)
# Out:
# Computing drought and waterlogging parameters for ABIE.BAL
# Computing drought and waterlogging parameters for ACER.RUB
# Computing drought and waterlogging parameters for PICE.MAR
# {'ABIE.BAL': {'H1': -1.37, 'H2': 3.05, 'H3': 137.94, 'H4': 137.94}, 'ACER.RUB': {'H1': -2.87, 'H2': 2.01, 'H3': 143.5, 'H4': 143.5}, 'PICE.MAR': {'H1': -1.37, 'H2': 3.05, 'H3': 144.6, 'H4': 144.6}}

# %% [markdown]
# ## Getting temperature-related parameter values from the litterature using regression
#
# These parameters are quite important as they regulate how the age cohorts react to change in temperature; PsnTMin, PsnTOpt and PsnTMax define a bell curve going from 0 (at PsnTMin and PsnTMax) to 1 (at PsnTOpt) to define fTemp, a reduction factor for the photosynthesis. This reduction factor will be multiplied by the theoretical photosynthesis done at a given month to reduce it. LeafOnMinT will define the minimum monthly temperature for leaves to be on the tree.
#
# Because of their definition (i.e. PsnTMin being "The average monthly temperature under which no photosynthesis happen, etc."), it's quite hard to get values for these parameters. See [notebook about future improvements](./100.Future_additions_todo.ipynb) for more discussion about it.
#
# As my time is limited, I went with a simple approach of statistical regression based on already published values, and a new dataset of species temperature ranges published by Morgane Dendoncker from theme 1 in DIVERSE for many species in north america. See [Dendoncker et al. 2026](https://www.sciencedirect.com/science/article/pii/S2666900526000079).
#
# By exploring the data, I noticed some strong correlations between some variables of [Dendoncker et al. 2026](https://www.sciencedirect.com/science/article/pii/S2666900526000079) and previously published values for these parameters. The causes of these correlation is quite obvious; for example, the fact that there is an important positive correlation between the 5th percentile of the average annual temperatures of where a tree species is located (one of the variables from [Dendoncker et al. 2026](https://www.sciencedirect.com/science/article/pii/S2666900526000079)) and PsnTMin is explained by the fact that at the northern edge of the species distribution (i.e. the 5th percentile of the temperatures in its range), the temperature becomes so low that the number of Growing Degrees Days (GDD) becomes close to what the species can survive, which implies that the average annual temperature becomes close to the minimum temperature for growth for the species.
#
# I constructed 4 different GAMs that were the most performant at predicting PsnTMin/TOpt/TMax and LeafOnMinT based on variables from [Dendoncker et al. 2026](https://www.sciencedirect.com/science/article/pii/S2666900526000079). The R squared are almost always above 0.9, indicating a very good fit, which we can see by comparing the values we predict compared to the ones used for training the model (in this case, I used the values published by Eric Gustafson in the user guide of PnET-Succession).
#
# This approach has the benefits of allowing us to get these parameters for many different tree species, as the data from [Dendoncker et al. 2026](https://www.sciencedirect.com/science/article/pii/S2666900526000079) spans a great number of species in North America. It will also allow us to be certain that the species are "ranked" between each other in terms of their temperature tolerance, and is rooted in empirical data (thanks to the work of [Dendoncker et al. 2026](https://www.sciencedirect.com/science/article/pii/S2666900526000079)). However, most of the approach relies on the values used by the training (here, the parameters of Eric Gustafson in the user guide). From discussion with him, Gustafson seem to have used maps of isoterms in the distribution of species that were available on the website of the initial PnET models. I was unable to find them.
#
# In the end, I expect this simple approach to be quite robust, and to produce parameters that will make for some quite realistic growing seasons; but a more localized calibration based on a new methodology is certainty possible. See [notebook about future improvments](./100.Future_additions_todo.ipynb) for a discussion on this.
#
# **The following code section will retrieve the temperature variables from [Dendoncker et al. 2026](https://www.sciencedirect.com/science/article/pii/S2666900526000079) for your species (using their full latin names indicated in a previous section in this notebook) and then use a Generalized Additive Model based on published data to interpolate the parameter values of LeanfOnMinT, PsnTMin, PsnTOpt and PsnTMax.**
#
# :::{warning} Do not run the following code cell if you want to keep your LeanfOnMinT, PsnTMin, PsnTOpt and PsnTMax parameters values as indicated in the tables above !
# Running this code cell will replace the values of LeanfOnMinT, PsnTMin, PsnTOpt and PsnTMax that you might have indicated in the table above with new values derived from this approach.
#
# Unless you have faith in the values you have indicated, I would recommend running the cell, because this approach (using the temperature variables from [Dendoncker et al. 2026](https://www.sciencedirect.com/science/article/pii/S2666900526000079)) will ensure that your species have values of LeanfOnMinT, PsnTMin, PsnTOpt and PsnTMax that rank them relative to each other in terms of temperature tolerance.
# :::

# %%
from functionsForCalibration import *
import json
import pandas as pd


with open("./SpeciesParametersSets/speciesNamesDictionnary.json", "r") as file: speciesNamesDictionnary = json.load(file)

dendonckerEtAlData = pd.read_csv("./ReferencesAndData/Others/DendonckerEtAl2026_Average_niche_all_spp.csv")

resultDict = {}

for speciesName in speciesNamesDictionnary:
    
    print(f"Computing temperature parameters for {speciesName}")
    # Getting the 3 climate variables we need from Dendoncker et al. 2026
    
    if speciesNamesDictionnary[speciesName] not in list(dendonckerEtAlData["Species"]):
        print("Species " + str(speciesNamesDictionnary[speciesName]) + " is not found in the data of Dendoncker et al. (2026). Please enter the information of the species manually :")
        MAT_q05 = -9999
        while MAT_q05 < -273:
            MAT_q05 = input("Please input MAT_q05 (5th percentile of the Mean Annual Temperature for the entire spatial distribution range of the species " + str(speciesNamesDictionnary[speciesName]) + ", i.e. the lowest annual temperatures in places where it survives) :")
        
        MAT_q95 = -9999
        while MAT_q95 < -273:
            MAT_q95 = input("Please input MAT_q95 (95th percentile of the Mean Annual Temperature for the entire spatial distribution range of the species " + str(speciesNamesDictionnary[speciesName]) + ", i.e. the highest annual temperatures in places where it survives) :")
        
        MTWM_q95 = -9999
        while MTWM_q95 < -273:
            MTWM_q95 = input("Please input MTWM_q95 (95th percentile of the Mean temperature of the Warmest Month for the entire spatial distribution range of the species " + str(speciesNamesDictionnary[speciesName]) + ", i.e. the highest mean temperature of the warmest month in places where it survives) :")
        
    # If the species is in the dataset, we get the values from the dataset.
    else:
        rowWithSpecies = dendonckerEtAlData[dendonckerEtAlData["Species"] == speciesNamesDictionnary[speciesName]]
        MAT_q05 = list(rowWithSpecies["MAT.q05"])[0]
        MAT_q95 = list(rowWithSpecies["MAT.q95"])[0]
        MTWM_q95 = list(rowWithSpecies["MTWM.q95"])[0]


    resultDict.update(predict_temperature_parameters_single_species(
                        species_code = speciesName,
                        species_latin_name = speciesNamesDictionnary[speciesName],
                        MAT_q05 = MAT_q05,
                        MAT_q95 = MAT_q95,
                        MTWM_q95 = MTWM_q95,
                        return_df = False,
                        plotAndSummaries = False)[0])


# # The function already takes the variables from the dendoncker et al. 2026 data
# # see functionsForCalibration.py for the hardcoded paths to the .csv files
# resultDict = predict_temperature_parameters(speciesNamesDictionnary, return_df = False, plotAndSummaries = False)

print(resultDict)

# Re-writing parameter dicts
DictOfCoreSpeciesParameters = json.load(open('./SpeciesParametersSets/Initial/coreSpeciesParameters.json'))
DictOfPnETSpeciesParameters = json.load(open('./SpeciesParametersSets/Initial/PnETSpeciesParameters.json'))
DictOfPnETGenericParameters = json.load(open('./SpeciesParametersSets/Initial/genericParameters.json'))

for species in resultDict:
    DictOfPnETSpeciesParameters["PnETSpeciesParameters"][species]["PsnTMin"] = str(round(resultDict[species]["PsnTMin"],2))
    DictOfPnETSpeciesParameters["PnETSpeciesParameters"][species]["PsnTOpt"] = str(round(resultDict[species]["PsnTOpt"],2))
    DictOfPnETSpeciesParameters["PnETSpeciesParameters"][species]["PsnTMax"] = str(round(resultDict[species]["PsnTMax"],2))
    DictOfPnETSpeciesParameters["PnETSpeciesParameters"][species]["LeafOnMinT"] = str(round(resultDict[species]["LeafOnMinT"],2))

with open("./SpeciesParametersSets/Initial/coreSpeciesParameters.json", "w") as f: json.dump(DictOfCoreSpeciesParameters, f)
with open("./SpeciesParametersSets/Initial/PnETSpeciesParameters.json", "w") as f: json.dump(DictOfPnETSpeciesParameters, f)
with open("./SpeciesParametersSets/Initial/genericParameters.json", "w") as f: json.dump(DictOfPnETGenericParameters, f)
# Out:
# Computing temperature parameters for ABIE.BAL
# Computing temperature parameters for ACER.RUB
# Computing temperature parameters for PICE.MAR
# {'ABIE.BAL': {'PsnTMin': 0.34, 'PsnTOpt': 15.9, 'PsnTMax': 27.79, 'LeafOnMinT': 1.61}, 'ACER.RUB': {'PsnTMin': 1.52, 'PsnTOpt': 27.14, 'PsnTMax': 33.87, 'LeafOnMinT': 2.37}, 'PICE.MAR': {'PsnTMin': 0.24, 'PsnTOpt': 16.76, 'PsnTMax': 27.03, 'LeafOnMinT': 1.54}}

# %% [markdown]
# ## Generating a full species parameter set for PnET-Succession using shade/drought/waterlogging tolerance, temperature information, and evergreen/deciduous status
#
# It might be that you find yourself without initial values for a given species that you want to calibrate; maybe because this tree species has never been calibrated/parameterized in PnET-Succession of in the PnET models at large, or maybe there are a lot of parameters for which you don't have initial values.
#
# The following code cell is made to generate a full species parameter set for several species for which you have a full Latin name. This is done by using the calibration tips of Eric Gustafson in the [user guide of PnET-Succession v5.1](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf). In it, Eric proposes initial parameters values dependant on wherever your species in a deciduous or evergreen tree, and its shade tolerance. It's far from ideal; but seeing that Eric is one of the most knowledgeable experts on the model, I think it's a good start.
#
# The drought and temperature tolerance parameters will be derived using the same methodology as the previous code sections. For the rest of the parameters, the rules with which they will be derived can be found in the [user guide of PnET-Succession v5.1](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf). The evergreen/deciduous type and the shade tolerance for the species is derived from the dataset of [Niinemets and Valladares 2006](https://onlinelibrary.wiley.com/doi/abs/10.1890/0012-9615%282006%29076%5B0521%3ATTSDAW%5D2.0.CO%3B2). **If your tree species cannot be found in the dataset, then the function will not work**; you will have to provide your own shade tolerance and evergreen/deciduous classification. The shade tolerance must range from 1 (very intolerant to shade) to 5 (very tolerant).
#
# **To use the code cell, simply provide the code and full Latin name of the species for which you want to generate a full species parameter set at the beginning of the code**.
#
# :::{warning} If you indicate species for which you have already indicated parameters above, the values of their parameters will be replaced !
# Simply make sure that the species you indicate here don't have parameters already indicated in the tables of the previous sections, or the following code cell will simply replace these values.
# :::
#
# :::{warning} This code cell only generate PnET-Succession species parameters; you might still need to provide core species parameters !
# The core species parameters of LANDIS-II (longevity, effective dispersal distance, vegetative reproduction probability, etc.) are not dealt with by the following code cell. This is because these parameter (which correspond to life history traits of the species) are more difficult to find, and you cannot predict them using the simple rules proposed by Eric Gustafson.
#
# To facilitate our calibration of tree species in Canada, I have compiled published values of these parameters for as many canadian species as possible and tried to find these values using the sources often used in LANDIS-II studies for these species. The code will therefore retrieve these and add them to the .json file containing the initial core species parameters values.
#
# If one of the species you want to calibrate isn't found in the parameters I have compiled, you will get an error message saying that you need to find these parameters by yourself. See the section about parameter sources above for some potential sources to help you find them. If you have no source, you will surely require expert opinion. Once you have obtained them, indicate these core species parameters in the corresponding table in the previous sections. You don't need to add these species to the PnET-Succession species parameter table that comes afterward, as these parameters will be obtained by the following code cell.
# :::
#
# :::{warning} SLWmax is derived from the published data of [Diaz et al. 2022](https://www.nature.com/articles/s41597-022-01774-9)
# With a bit of trial and error, I've noticed that the SLWmax values predicted from the propositions of Eric Gustafson in the [user guide of PnET-Succession v5.1](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf) were not always very good, especially for some peculiar species like the Tamarack (*Larix laricina*).
#
# Therefore, I've downloaded and used the data of [Diaz et al. 2022](https://www.nature.com/articles/s41597-022-01774-9) which contains values of LMA (Leaf Mass Area), which is the same thing as the Specific Leaf Weight (SLW). I've taken the dataset and removed all non-tree species from it, and removed columns that were not useful to my use here.
#
# However, what we need is SLWmax, while the measure in the [Diaz et al. 2022](https://www.nature.com/articles/s41597-022-01774-9) dataset is most likely the average SLW of leaves for a species.
#
# To derive SLWmax from the LMA of [Diaz et al. 2022](https://www.nature.com/articles/s41597-022-01774-9) (that I will now call $SLW_{avg}$), I therefore used the following equation that is based on the parameter SLWDel and the IMAX generic parameter :
#
# $SLWmax = \frac{SLW_{avg}}{1 - \left( SLWDel \times \frac{IMAX - 1}{2} \right)}$
#
# This formula accounts for the fact that PnET-Succession distributes foliage into IMAX with even proportions, and reduces the specific leaf weight linearly from the top sublayer (SLWmax) to the bottom sublayer based on the SLWDel proportion. For example, if SLWDel=0.2 (the standard value for deciduous species), the SLW of each subsequent sublayer decreases by 20% of the SLWmax value. This creates an arithmetic progression:
# - Sublayer 1: SLWmax×1.0
# - Sublayer 2: SLWmax×(1−SLWDel)
# - Sublayer 3: SLWmax×(1−2×SLWDel)
# - ...and so on for IMAX layers.
#
# Therefore, using this formula means that the average of SLW accross the layers will be equal to the value found in [Diaz et al. 2022](https://www.nature.com/articles/s41597-022-01774-9) for the species for the given SLWmax we will find.
#
# Not that while the dataset contains a measure of nitrogen in the leaves (Nmass), I haven't used it to derive the FolN parameter. This is because in the [user guide of PnET-Succession v5.1](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf), Eric Gustafson says that it is more important to make sure that FolN is ranked relative to the shade tolerance of the species simulated, rather than using empirical values. Therefore, I believe that using the FolN scale that changes with the shade tolerance of a species as Gustafson proposes is a better way of doing things here.
# :::

# %%
from functionsForCalibration import *
import json
import pandas as pd
import os


# Load dictionnary of additional species codes/full latin names
# INDICATE THE NAME OF THE SPECIES FOR WHICH YOU WANT AN ADDITIONAL PARAMETER SET HERE !
# BE CERTAIN TO INDICATE THEIR FULL LATIN NAME CORRECTLY : It is used for a lookup in different datasets.
additionalSpeciesNamesDictionnary = {
    "ACER.SAH":"Acer saccharum",
    "LARI.LAR":"Larix laricina",
    "POPU.TRE":"Populus tremuloides"
}

niinemetsValladaresData = pd.read_csv("./ReferencesAndData/Others/NiinemetsEtValladares_AppendixTable_full.csv")

dendonckerEtAlData = pd.read_csv("./ReferencesAndData/Others/DendonckerEtAl2026_Average_niche_all_spp.csv")

resultDict = {}

# For each species,
for speciesName in additionalSpeciesNamesDictionnary:
    print(f"Getting parameters for {speciesName}")
    resultDict[speciesName] = dict()
    
    # Get shade tolerance/Drought tolerance and tree/wood type from niinemets and al.
    # If the species is not found in Niinemets and Valladares, we ask for a manual input.
    if additionalSpeciesNamesDictionnary[speciesName] not in list(niinemetsValladaresData["Species"]):
        print("Species " + str(additionalSpeciesNamesDictionnary[speciesName]) + " is not found in the data of Niinemets and Valladares (2006). Please enter the information of the species manually :")
        shade_tolerance = -999
        while shade_tolerance < 1 or shade_tolerance > 5:
            shade_tolerance = float(input("Please input the shade tolerance of " + str(additionalSpeciesNamesDictionnary[speciesName]) + " (from 1 = very intolerant to 5 = very tolerant"))
        tree_type = "none"
        while tree_type != "evergreen" and tree_type != "deciduous":
            tree_type = input("Please input the tree type (evergreen or deciduous) of " + str(additionalSpeciesNamesDictionnary[speciesName]) + " :")
        wood_type = "none"
        while wood_type != "hardwood" and tree_type != "softwood":
            wood_type = input("Please input the wood type type (hardwood or softwood) of " + str(additionalSpeciesNamesDictionnary[speciesName]) + " :")
    # If the species is in Niinemets and Valladares, we get the values from the dataset.
    else:
        rowWithSpecies = niinemetsValladaresData[niinemetsValladaresData["Species"] == additionalSpeciesNamesDictionnary[speciesName]]
        # Some values in the dataset of Niinemets and Valladares are inferior to 1 or superior to 5;
        # not sure why. Not explained in the article. We deal with these situations by cropping the values to 1-5.
        shade_tolerance = min(5 , max(1, list(rowWithSpecies["Shade tolerance"])[0]))
        if list(rowWithSpecies["Evergreen"])[0] == "Y":
            tree_type = "evergreen"
        else:
            tree_type = "deciduous"
        if list(rowWithSpecies["Gymnosperm"])[0] == "Y":
            wood_type = "softwood"
        else:
            wood_type = "hardwood"

    # This function uses the rules indicated by Eric Gustafson in the user guide of PnET-Succession v5.1.
    # There is two parameters from which Gustafson has no rule to get them : TOFol and FrActWd.
    # For these, I used the averaged values for deciduous/evergreen and hardwood/softwoods in previous publications of PnET-Succession parameters
    # this gives the following :
    # - TOFol : 1 for deciduous trees, 0.3 for evergreens
    # - FrActWd : 0.000035 for hardwoods, 0.000029 for softwoods

    # We retrieve the parameter IMAX, which is needed for computing SLWmax in the following function
    IMAX = json.load(open('./SpeciesParametersSets/Initial/genericParameters.json'))["IMAX"]
    resultDict[speciesName].update(get_parameters_gustafson_rules(shade_tolerance,
                                                                  tree_type,
                                                                  wood_type,
                                                                 additionalSpeciesNamesDictionnary[speciesName],
                                                                 IMAX))


    ############################################################
    # Get the values of H1/H2/H3/H4
    # Getting drought and wl tolerance from NiinemetsAndValladares
    # Again, if the species is not in the niinemets and valladares dataset, we ask for the data
    if additionalSpeciesNamesDictionnary[speciesName] not in list(niinemetsValladaresData["Species"]):
        print("Species " + str(additionalSpeciesNamesDictionnary[speciesName]) + " is not found in the data of Niinemets and Valladares (2006). Please enter the information of the species manually :")
        drought_tolerance = -999
        while drought_tolerance < 1 or drought_tolerance > 5:
            drought_tolerance = float(input("Please input the drought tolerance of " + str(additionalSpeciesNamesDictionnary[speciesName]) + " (from 1 = very intolerant to 5 = very tolerant"))
        waterlogging_tolerance = -999
        while waterlogging_tolerance < 1 or waterlogging_tolerance > 5:
            waterlogging_tolerance = float(input("Please input the waterlogging tolerance of " + str(additionalSpeciesNamesDictionnary[speciesName]) + " (from 1 = very intolerant to 5 = very tolerant"))

    # If the species is in Niinemets and Valladares, we get the values from the dataset.
    else:
        rowWithSpecies = niinemetsValladaresData[niinemetsValladaresData["Species"] == additionalSpeciesNamesDictionnary[speciesName]]
        drought_tolerance = min(5 , max(1, list(rowWithSpecies["Drought tolerance"])[0]))
        waterlogging_tolerance = min(5 , max(1, list(rowWithSpecies["Waterlogging tolerance"])[0]))
    
    resultDict[speciesName].update(predict_H_parameters(
    drought_tolerance=drought_tolerance,
    waterlogging_tolerance=waterlogging_tolerance,
    plot=False,
    gam_summary=False
    ))
    
    # Getting the values for the temperature parameters
    # if the species is not in the Dendoncker et al. dataset, we ask for the data
    if additionalSpeciesNamesDictionnary[speciesName] not in list(dendonckerEtAlData["Species"]):
        print("Species " + str(additionalSpeciesNamesDictionnary[speciesName]) + " is not found in the data of Dendoncker et al. (2026). Please enter the information of the species manually :")
        MAT_q05 = -9999
        while MAT_q05 < -273:
            MAT_q05 = float(input("Please input MAT_q05 (5th percentile of the Mean Annual Temperature for the entire spatial distribution range of the species " + str(additionalSpeciesNamesDictionnary[speciesName]) + ", i.e. the lowest annual temperatures in places where it survives) :"))
        
        MAT_q95 = -9999
        while MAT_q95 < -273:
            MAT_q95 = float(input("Please input MAT_q95 (95th percentile of the Mean Annual Temperature for the entire spatial distribution range of the species " + str(additionalSpeciesNamesDictionnary[speciesName]) + ", i.e. the highest annual temperatures in places where it survives) :"))
        
        MTWM_q95 = -9999
        while MTWM_q95 < -273:
            MTWM_q95 = float(input("Please input MTWM_q95 (95th percentile of the Mean temperature of the Warmest Month for the entire spatial distribution range of the species " + str(additionalSpeciesNamesDictionnary[speciesName]) + ", i.e. the highest mean temperature of the warmest month in places where it survives) :"))
        
    # If the species is in the dataset, we get the values from the dataset.
    else:
        rowWithSpecies = dendonckerEtAlData[dendonckerEtAlData["Species"] == additionalSpeciesNamesDictionnary[speciesName]]
        MAT_q05 = list(rowWithSpecies["MAT.q05"])[0]
        MAT_q95 = list(rowWithSpecies["MAT.q95"])[0]
        MTWM_q95 = list(rowWithSpecies["MTWM.q95"])[0]
    
    resultDict[speciesName].update(predict_temperature_parameters_single_species(
                        species_code = speciesName,
                        species_latin_name = additionalSpeciesNamesDictionnary[speciesName],
                        MAT_q05 = MAT_q05,
                        MAT_q95 = MAT_q95,
                        MTWM_q95 = MTWM_q95,
                        return_df = False,
                        plotAndSummaries = False)[0][speciesName])

    
    print(resultDict[speciesName])
    print("\n")


# Export the new species to the existing .json files
DictOfCoreSpeciesParameters = json.load(open('./SpeciesParametersSets/Initial/coreSpeciesParameters.json'))
# In case no initial PnET Species parameters exist
if os.path.exists('./SpeciesParametersSets/Initial/PnETSpeciesParameters.json'):
    DictOfPnETSpeciesParameters = json.load(open('./SpeciesParametersSets/Initial/PnETSpeciesParameters.json'))
else:
    DictOfPnETSpeciesParameters = dict()
    DictOfPnETSpeciesParameters["LandisData"] = "PnETSpeciesParameters"
    DictOfPnETSpeciesParameters["PnETSpeciesParameters"] = dict()
DictOfPnETGenericParameters = json.load(open('./SpeciesParametersSets/Initial/genericParameters.json'))

for species in resultDict:
    DictOfPnETSpeciesParameters["PnETSpeciesParameters"][species] = dict()
    for parameter in resultDict[species]:
        DictOfPnETSpeciesParameters["PnETSpeciesParameters"][species][parameter] = str(resultDict[species][parameter])

for species in DictOfPnETSpeciesParameters["PnETSpeciesParameters"]:
    # We put the parameters in the same order for all species
    DictOfPnETSpeciesParameters["PnETSpeciesParameters"][species] = {k: DictOfPnETSpeciesParameters["PnETSpeciesParameters"][species][k] for k in sorted(DictOfPnETSpeciesParameters["PnETSpeciesParameters"][species])}

with open("./SpeciesParametersSets/Initial/coreSpeciesParameters.json", "w") as f: json.dump(DictOfCoreSpeciesParameters, f)
with open("./SpeciesParametersSets/Initial/PnETSpeciesParameters.json", "w") as f: json.dump(DictOfPnETSpeciesParameters, f)
with open("./SpeciesParametersSets/Initial/genericParameters.json", "w") as f: json.dump(DictOfPnETGenericParameters, f)

# At the end : add the additional species codes/full latin names to the existing species dictionnary name
with open('./SpeciesParametersSets/speciesNamesDictionnary.json', 'r') as file: speciesDict = json.load(file)
speciesDict.update(additionalSpeciesNamesDictionnary)
with open("./SpeciesParametersSets/speciesNamesDictionnary.json", "w") as f: json.dump(speciesDict, f)

# We also edit the names in the core parameter file
coreSpeciesParameters = json.load(open('./SpeciesParametersSets/Initial/coreSpeciesParameters.json', 'r'))
for key in additionalSpeciesNamesDictionnary.keys():
    # print(key)
    # print(speciesCodeDict[key])
    coreSpeciesParameters = replace_in_dict(coreSpeciesParameters, additionalSpeciesNamesDictionnary[key], key)
with open('./SpeciesParametersSets/Initial/coreSpeciesParameters.json', 'w') as json_file:
    # Step 4: Write the dictionary to the file
    json.dump(coreSpeciesParameters, json_file)
# Out:
# Getting parameters for ACER.SAH
# {'HalfSat': '157.412', 'FolN': '2.2632', 'SLWmax': '76.918333', 'FracFol': '0.013664', 'EstRad': '0.972416', 'CFracBiomass': '0.494', 'AmaxA': '-46.0', 'AmaxB': '71.9', 'k': '0.58', 'TOWood': '0.03', 'TORoot': '0.03', 'KWdLit': '0.075', 'SLWDel': '0.2', 'FracFolShape': '6', 'MaxFracFol': '0.013664', 'EstMoist': '1', 'TOFol': '1.0', 'FrActWd': '3.5e-05', 'H1': -0.17, 'H2': 3.94, 'H3': 146.35, 'H4': 146.35, 'PsnTMin': 1.53, 'PsnTOpt': 23.35, 'PsnTMax': 30.95, 'LeafOnMinT': 2.37}
#
#
# Getting parameters for LARI.LAR
# ...
